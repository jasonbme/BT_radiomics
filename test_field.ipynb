# %%
import pandas as pd
import numpy as np
from collections import Counter
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,cohen_kappa_score, matthews_corrcoef
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import statistics

pd.options.mode.chained_assignment = None

# %%
def train_test_data_split(raw_data, train_mapping, test_mapping):
    train_data = pd.DataFrame(columns=raw_data.columns)
    test_data = pd.DataFrame(columns=raw_data.columns)
    
    for case_id in raw_data.index:
        case_general_id = case_id[0:20]
        if case_general_id in train_mapping.values[:,1]:
            train_data.loc[case_id]= raw_data.loc[case_id, :]
        elif case_general_id in test_mapping.values[:,1]:
            test_data.loc[case_id]= raw_data.loc[case_id, :]
            
    return train_data, test_data

# %%
def select_features(dataset, number_of_features):
    X = dataset.loc[:, dataset.columns != "Grade"]
    Y = dataset.loc[:, "Grade"]
    
    standard_scaler = StandardScaler().fit(X)
    X[X.columns] = standard_scaler.fit_transform(X[X.columns])
    
    select_k_best = SelectKBest(f_classif).fit(X, Y)
    
    scored_features = pd.DataFrame({'Feature':list(X.columns), 'Score':select_k_best.scores_})
    scored_features.sort_values(by='Score', ascending=False, inplace=True)
    scored_features.to_csv("output/scored_features.csv")
    
    best_features = scored_features.nlargest(number_of_features,'Score')
    best_features = best_features.loc[:, "Feature"]
    # print("Selected features: ")
    # print(best_features)
    best_features.to_csv("output/best_features.csv")

    selected_features = X.loc[dataset.index, best_features]
    selected_features["Grade"] = Y
    
    return selected_features

# %%
def equalize_dataset(dataset):
    is_HGG =  dataset['Grade']=='HGG'
    is_LGG =  dataset['Grade']=='LGG'
    hggs = dataset[is_HGG]
    lggs = dataset[is_LGG]
    hggs = hggs.sample(n=len(lggs))
    equalized_mapping = pd.concat([hggs, lggs])
    return equalized_mapping

# %%
dataset = pd.read_csv("output/features.csv", index_col=0)
name_mapping = pd.read_csv("mapping/name_mapping.csv")

skf = StratifiedKFold(n_splits=5)

X = name_mapping.values[:,1]
y = name_mapping.values[:,0]

number_of_features = 10

etd = None

for train_index, test_index in skf.split(X, y):
     
    X_train, X_test = X[train_index], X[test_index] 
    y_train, y_test = y[train_index], y[test_index]
        
    print("Train labels distribution:", Counter(y_train))
    print("Test labels distribution:",Counter(y_test))
    print("\n")

    train_mapping = pd.DataFrame({'Grade': y_train, 'ID': X_train})    
    test_mapping = pd.DataFrame({'Grade': y_test, 'ID': X_test})
        
    (train_dataset, test_dataset) = train_test_data_split(dataset, train_mapping, test_mapping)
    
    reduced_train_dataset = select_features(train_dataset, number_of_features)
    
    equalized_train_dataset = equalize_dataset(reduced_train_dataset)
    
    print("Size of equalized dataset: ", (len(equalized_train_dataset)/4))
# Out:
# Train labels distribution: Counter({'HGG': 233, 'LGG': 61})
# Test labels distribution: Counter({'HGG': 59, 'LGG': 15})
#
#
# Size of equalized dataset:  122.0
# Train labels distribution: Counter({'HGG': 233, 'LGG': 61})
# Test labels distribution: Counter({'HGG': 59, 'LGG': 15})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/cy/4fv0jb6n2q30z5ddjjtghjqh0000gn/T/ipykernel_40991/3305799976.py in <module>
#      23     test_mapping = pd.DataFrame({'Grade': y_test, 'ID': X_test})
#      24
# ---> 25     (train_dataset, test_dataset) = train_test_data_split(dataset, train_mapping, test_mapping)
#      26
#      27     reduced_train_dataset = select_features(train_dataset, number_of_features)
#
# /var/folders/cy/4fv0jb6n2q30z5ddjjtghjqh0000gn/T/ipykernel_40991/3162368263.py in train_test_data_split(raw_data, train_mapping, test_mapping)
#       6         case_general_id = case_id[0:20]
#       7         if case_general_id in train_mapping.values[:,1]:
# ----> 8             train_data.loc[case_id]= raw_data.loc[case_id, :]
#       9         elif case_general_id in test_mapping.values[:,1]:
#      10             test_data.loc[case_id]= raw_data.loc[case_id, :]
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1722
#    1723             if missing:
# -> 1724                 self._setitem_with_indexer_missing(indexer, value)
#    1725                 return
#    1726
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2029                 value = Series(value, index=self.obj.columns, name=indexer)
#    2030
# -> 2031             self.obj._mgr = self.obj.append(value)._mgr
#    2032             self.obj._maybe_update_cacher(clear=True)
#    2033
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8967                 ignore_index=ignore_index,
#    8968                 verify_integrity=verify_integrity,
# -> 8969                 sort=sort,
#    8970             )
#    8971         ).__finalize__(self, method="append")
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     477         self.copy = copy
#     478
# --> 479         self.new_axes = self._get_new_axes()
#     480
#     481     def get_result(self):
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     549         return [
#     550             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
# --> 551             for i in range(ndim)
#     552         ]
#     553
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     549         return [
#     550             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
# --> 551             for i in range(ndim)
#     552         ]
#     553
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     603
#     604         if self.keys is None:
# --> 605             concat_axis = _concat_indexes(indexes)
#     606         else:
#     607             concat_axis = _make_concat_multiindex(
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _concat_indexes(indexes)
#     621
#     622 def _concat_indexes(indexes) -> Index:
# --> 623     return indexes[0].append(indexes[1:])
#     624
#     625
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/indexes/base.py in append(self, other)
#    4678         name = None if len(names) > 1 else self.name
#    4679
# -> 4680         return self._concat(to_concat, name)
#    4681
#    4682     def _concat(self, to_concat: list[Index], name: Hashable) -> Index:
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/indexes/base.py in _concat(self, to_concat, name)
#    4687
#    4688         result = concat_compat(to_concat_vals)
# -> 4689         return Index(result, name=name)
#    4690
#    4691     def putmask(self, mask, value) -> Index:
#
# /opt/miniconda3/envs/thesis/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     387
#     388         from pandas.core.arrays import PandasArray
# --> 389         from pandas.core.indexes.range import RangeIndex
#     390
#     391         name = maybe_extract_name(name, data, cls)
#
# /opt/miniconda3/envs/thesis/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
rds
# Out:
#                             original_glcm_Idn  \
# BraTS20_Training_001_FLAIR           0.677054
# BraTS20_Training_001_T1              1.221874
# BraTS20_Training_001_T1C             0.292287
# BraTS20_Training_001_T2              0.821166
# BraTS20_Training_002_FLAIR          -1.000550
# ...                                       ...
# BraTS20_Training_296_T2              1.103441
# BraTS20_Training_297_FLAIR           0.548815
# BraTS20_Training_297_T1              0.617123
# BraTS20_Training_297_T1C             0.096448
# BraTS20_Training_297_T2              1.416745
#
#                             original_gldm_LargeDependenceHighGrayLevelEmphasis  \
# BraTS20_Training_001_FLAIR                                           0.210019
# BraTS20_Training_001_T1                                              0.378783
# BraTS20_Training_001_T1C                                            -0.093218
# BraTS20_Training_001_T2                                             -0.118250
# BraTS20_Training_002_FLAIR                                          -0.279260
# ...                                                                       ...
# BraTS20_Training_296_T2                                              1.114477
# BraTS20_Training_297_FLAIR                                           0.486037
# BraTS20_Training_297_T1                                              0.931837
# BraTS20_Training_297_T1C                                             0.472833
# BraTS20_Training_297_T2                                              0.031743
#
#                             original_glcm_InverseVariance  \
# BraTS20_Training_001_FLAIR                       0.524749
# BraTS20_Training_001_T1                          0.486353
# BraTS20_Training_001_T1C                         0.421201
# BraTS20_Training_001_T2                         -0.319973
# BraTS20_Training_002_FLAIR                       0.305009
# ...                                                   ...
# BraTS20_Training_296_T2                          0.515131
# BraTS20_Training_297_FLAIR                       0.484225
# BraTS20_Training_297_T1                         -0.414453
# BraTS20_Training_297_T1C                        -1.664356
# BraTS20_Training_297_T2                         -0.559769
#
#                             original_glrlm_RunEntropy  \
# BraTS20_Training_001_FLAIR                  -0.001946
# BraTS20_Training_001_T1                      0.356023
# BraTS20_Training_001_T1C                    -0.132266
# BraTS20_Training_001_T2                      0.012178
# BraTS20_Training_002_FLAIR                   0.333196
# ...                                               ...
# BraTS20_Training_296_T2                      0.347981
# BraTS20_Training_297_FLAIR                  -0.242740
# BraTS20_Training_297_T1                      1.151393
# BraTS20_Training_297_T1C                     1.457248
# BraTS20_Training_297_T2                      2.792827
#
#                             original_gldm_SmallDependenceLowGrayLevelEmphasis  \
# BraTS20_Training_001_FLAIR                                          -0.915236
# BraTS20_Training_001_T1                                             -1.069613
# BraTS20_Training_001_T1C                                            -0.842367
# BraTS20_Training_001_T2                                             -0.795128
# BraTS20_Training_002_FLAIR                                           0.376283
# ...                                                                       ...
# BraTS20_Training_296_T2                                             -1.122091
# BraTS20_Training_297_FLAIR                                          -0.956670
# BraTS20_Training_297_T1                                             -0.987561
# BraTS20_Training_297_T1C                                            -0.965526
# BraTS20_Training_297_T2                                             -0.698864
#
#                             original_glcm_SumAverage  \
# BraTS20_Training_001_FLAIR                 -0.061814
# BraTS20_Training_001_T1                    -0.025435
# BraTS20_Training_001_T1C                    0.031282
# BraTS20_Training_001_T2                    -0.295421
# BraTS20_Training_002_FLAIR                 -0.149899
# ...                                              ...
# BraTS20_Training_296_T2                     0.341558
# BraTS20_Training_297_FLAIR                  0.234500
# BraTS20_Training_297_T1                     0.766157
# BraTS20_Training_297_T1C                    1.152712
# BraTS20_Training_297_T2                     0.406004
#
#                             original_glcm_JointAverage  original_glcm_Idmn  \
# BraTS20_Training_001_FLAIR                   -0.061814            0.825877
# BraTS20_Training_001_T1                      -0.025435            1.180603
# BraTS20_Training_001_T1C                      0.031282            0.635376
# BraTS20_Training_001_T2                      -0.295421            0.677323
# BraTS20_Training_002_FLAIR                   -0.149899           -0.708334
# ...                                                ...                 ...
# BraTS20_Training_296_T2                       0.341558            1.187376
# BraTS20_Training_297_FLAIR                    0.234500            0.716939
# BraTS20_Training_297_T1                       0.766157            0.848403
# BraTS20_Training_297_T1C                      1.152712            0.552979
# BraTS20_Training_297_T2                       0.406004            1.311303
#
#                             original_glszm_LargeAreaHighGrayLevelEmphasis  \
# BraTS20_Training_001_FLAIR                                       1.365458
# BraTS20_Training_001_T1                                          2.311673
# BraTS20_Training_001_T1C                                         0.126898
# BraTS20_Training_001_T2                                          1.977581
# BraTS20_Training_002_FLAIR                                      -0.358986
# ...                                                                   ...
# BraTS20_Training_296_T2                                          2.335453
# BraTS20_Training_297_FLAIR                                      -0.183283
# BraTS20_Training_297_T1                                         -0.327857
# BraTS20_Training_297_T1C                                        -0.396218
# BraTS20_Training_297_T2                                         -0.403249
#
#                             original_shape_LeastAxisLength Grade
# BraTS20_Training_001_FLAIR                        1.419114   HGG
# BraTS20_Training_001_T1                           1.419114   HGG
# BraTS20_Training_001_T1C                          1.419114   HGG
# BraTS20_Training_001_T2                           1.419114   HGG
# BraTS20_Training_002_FLAIR                        0.059756   HGG
# ...                                                    ...   ...
# BraTS20_Training_296_T2                           1.824657   LGG
# BraTS20_Training_297_FLAIR                        0.110791   LGG
# BraTS20_Training_297_T1                           0.110791   LGG
# BraTS20_Training_297_T1C                          0.110791   LGG
# BraTS20_Training_297_T2                           0.110791   LGG
#
# [736 rows x 11 columns]
